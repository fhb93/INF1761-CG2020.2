# %% [markdown]
# <h1>CG20 Aula 5 - Transformada de Fourier</h1>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import fftpack
# %matplotlib notebook

# %%
path = '../dat/sgy/'
f3 = np.load(path + 'f3.npy')
_=plt.figure(figsize=[8,4])
plt.imshow(f3)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
f3.shape
# Out:
# (363, 951)

# %%
y = f3[:, 600]
dt = 4 / 1000
N = 363
T = N * dt
f = 1 / dt
t = np.arange(0, T, dt)
_= plt.figure(figsize=[8,4])
plt.plot(t,y)
plt.show()
print(f'sinal de {T} s com {N} amostras, dt={dt} e frequencia de amostragem = {f}')
# Out:
# <img src="data:image/png;base64,..." width="800">
# sinal de 1.452 s com 363 amostras, dt=0.004 e frequencia de amostragem = 250.0

# %%
Y = fftpack.fft(y)

delta_f = 1 / T

fmax = N * delta_f

f = np.arange(0, fmax / 2, delta_f)

Y_shift = np.fft.fftshift(Y)

plt.figure(figsize=(8, 4))
plt.plot(f, np.abs(Y[: 182]))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
h, w = f3.shape[:3]
print(f'(w,h) = ({w}{h}), dtype={f3.dtype}, min = {np.amin(f3)}, max = {np.amax(f3)}')
# Out:
# (w,h) = (951363), dtype=float32, min = -23018.0, max = 16310.0
